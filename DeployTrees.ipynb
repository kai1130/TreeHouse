# %%
from deploy import deploy_catalog

# %%
catalog = [
    {'category': 'Model',
     'name': 'Model H',
     'binpath': './contract_bytecode/models/model_h.bin',
     'callable': 'retrieve_model_dict',
    },
    {'category': 'Model',
     'name': 'Model B',
     'binpath': './contract_bytecode/models/model_b.bin',
     'callable': 'retrieve_model_dict',
    },
    {'category': 'Model',
     'name': 'Model A',
     'binpath': './contract_bytecode/models/model_a.bin',
     'callable': 'retrieve_model_dict',
    },
    {'category': 'Model',
     'name': 'Model R',
     'binpath': './contract_bytecode/models/model_r.bin',
     'callable': 'retrieve_model_dict',
    },
    {'category': 'Wheel',
     'name': 'W18',
     'binpath': './contract_bytecode/wheels/w18.bin',
     'callable': 'retrieve_wheel_dict',
    },
    {'category': 'Wheel',
     'name': 'W19',
     'binpath': './contract_bytecode/wheels/w19.bin',
     'callable': 'retrieve_wheel_dict',
    },
    {'category': 'Wheel',
     'name': 'W20',
     'binpath': './contract_bytecode/wheels/w20.bin',
     'callable': 'retrieve_wheel_dict',
    },
    {'category': 'Seat',
     'name': 'Black Seat',
     'binpath': './contract_bytecode/seats/black_seat.bin',
     'callable': 'retrieve_black_seat_dict',
    },
    {'category': 'Seat',
     'name': 'White Seat',
     'binpath': './contract_bytecode/seats/white_seat.bin',
     'callable': 'retrieve_white_seat_dict',
    },
]

# %%
catalog_df = deploy_catalog(catalog)
# Out:
# Deploying Model H to Hedera
#  - Contract Bytecode File: 0.0.14973363
#  - Contract ID: 0.0.14973364
#
# Deploying Model B to Hedera
#  - Contract Bytecode File: 0.0.14973365
#  - Contract ID: 0.0.14973366
#
# Deploying Model A to Hedera
#  - Contract Bytecode File: 0.0.14973367
#  - Contract ID: 0.0.14973368
#
# Deploying Model R to Hedera
#  - Contract Bytecode File: 0.0.14973369
#  - Contract ID: 0.0.14973370
#
# Deploying W18 to Hedera
#  - Contract Bytecode File: 0.0.14973371
#  - Contract ID: 0.0.14973372
#
# Deploying W19 to Hedera
#  - Contract Bytecode File: 0.0.14973373
#  - Contract ID: 0.0.14973374
#
# Deploying W20 to Hedera
#  - Contract Bytecode File: 0.0.14973375
#  - Contract ID: 0.0.14973376
#
# Deploying Black Seat to Hedera
#  - Contract Bytecode File: 0.0.14973377
#  - Contract ID: 0.0.14973378
#
# Deploying White Seat to Hedera
#  - Contract Bytecode File: 0.0.14973379
#  - Contract ID: 0.0.14973380

# %%
catalog_df.head()
# Out:
#   category     name                                 binpath  \
# 0    Model  Model H  ./contract_bytecode/models/model_h.bin
# 1    Model  Model B  ./contract_bytecode/models/model_b.bin
# 2    Model  Model A  ./contract_bytecode/models/model_a.bin
# 3    Model  Model R  ./contract_bytecode/models/model_r.bin
# 4    Wheel      W18      ./contract_bytecode/wheels/w18.bin
#
#               callable   contract_id
# 0  retrieve_model_dict  0.0.14973364
# 1  retrieve_model_dict  0.0.14973366
# 2  retrieve_model_dict  0.0.14973368
# 3  retrieve_model_dict  0.0.14973370
# 4  retrieve_wheel_dict  0.0.14973372

# %%
catalog_df.to_csv('./catalog.csv', index=False)
