# %%
import json
from configurator import Configurator

with open('./options.json') as f:
    options = json.load(f)

# %%
configurator = Configurator(options)

# %%
configurator.set_name('Kai')
configurator.set_location('9800 Airport Blvd, San Antonio, TX 78216')

# %%
configurator.select_model('Model H') # to be a dropdown

# %%
configurator.select_seats('White Seat') # to be a dropdown

# %%
configurator.select_wheels('W19') # to be a dropdown

# %%
configurator.set_coords() # set coords of all addresses

# %%
configurator.sum_mat() # sum materials
configurator.get_cumul_weight()

# %%
configurator.get_nodes() # hi

# %%
configurator.calc_edges() # artificial intelligence blockchain big data quantum computing
configurator.calc_user_edge()

# %%
configurator.get_kgm()

# %%
configurator.kgm
# Out:
# 1789114.473482402

# %%
configurator.plot()
# Out:
# {
#   "initialViewState": {
#     "latitude": 0,
#     "longitude": 0,
#     "maxZoom": 3,
#     "minZoom": 0.5,
#     "zoom": 1
#   },
#   "layers": [
#     {
#       "@@type": "LineLayer",
#       "autoHighlight": true,
#       "data": [
#         {
#           "cumul_weight": 100,
#           "distance": 1510.6163173753025,
#           "end": [
#             -99.0805443,
#             19.4375028
#           ],
#           "name": "White Seat -> Model H",
#           "start": [
#             -97.0403352,
#             32.8998091
#           ]
#         },
#         {
#           "cumul_weight": 100,
#           "distance": 8396.641135536738,
#           "end": [
#             13.510658,
#             52.364628
#           ],
#           "name": "W19 -> Model H",
#           "start": [
#             -97.0403352,
#             32.8998091
#           ]
#         },
#         {
#           "cumul_weight": 2000,
#           "distance": 399.1943640955989,
#           "end": [
# ...

# %%
configurator.options
# Out:
# [{'price': 40000,
#   'materials': {'metal': 1000, 'plastic': 400},
#   'addr': 'DFW International Airport (DFW), 2400 Aviation Dr, DFW Airport, TX 75261, USA',
#   'name': 'Model H',
#   'manufacturer': 'Hedera Motors Dallas',
#   'weight': 1800,
#   'lat': 32.8998091,
#   'lng': -97.0403352},
#  {'price': 1000,
#   'materials': {'leatherette': 15, 'metal': 20},
#   'addr': 'Av. Capitán Carlos León, Ciudad de México, CDMX, Mexico',
#   'name': 'White Seat',
#   'manufacturer': 'Mexico City Seat Company',
#   'lat': 19.4375028,
#   'weight': 100,
#   'lng': -99.0805443},
#  {'price': 1000,
#   'materials': {'rubber': 11, 'metal': 38},
#   'addr': 'Melli-Beese-Ring 1, 12529 Schönefeld, Germany',
#   'name': 'W19',
#   'manufacturer': 'Berlin Wheel Company Ltd',
#   'lat': 52.364628,
#   'weight': 100,
#   'lng': 13.510658}]
